# %% [markdown]
# ## 🆕 New Column Explorer in Databricks Notebooks
#
# You can now use the **Column Explorer** when working with **tabular notebook outputs**:
#
# - 🔍 **Search Columns**: Quickly find specific columns by name.
# - 👁️ **Show or Hide Columns**: Toggle visibility for better focus.
# - 📌 **Pin Columns**: Keep important columns in view while scrolling.
# - 🔃 **Rearrange Columns**: Drag and drop to reorder columns as needed.
#
# ---
#
# ## 📥 Download as Excel (New)
#
# - ✅ Now supported for **notebooks connected to serverless compute**.
# - 📄 Easily **export your notebook output tables to Excel (.xlsx)** format for sharing and analysis.

# %%
bronze_df = spark.read.table("pokemon_bronze.kanto.team_rocket")
display(bronze_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### Control the location of Databricks Assistant with the new docking feature
